# %% [markdown]
# <a href="https://colab.research.google.com/github/Vageeswari-kanchiuniv/C/blob/main/Data_Analysis_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Data Analysis with Python
# Demonstration of **Data Loading, Data Wrangling, Data Exploration, Aggregation, and Visualization** using Pandas, NumPy, Matplotlib, and Seaborn.

# %% [markdown]
# ## 🔹 1. Data Loading
# We will create a **sample employee dataset** inside the program (no external file required).

# %%
import pandas as pd
import numpy as np

# Sample dataset
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace", "Helen"],
    "Department": ["HR", "IT", "IT", "Finance", "Finance", "HR", "IT", "Finance"],
    "Salary": [50000, 60000, 75000, 80000, np.nan, 55000, 70000, 90000],
    "Age": [25, 30, 35, 40, 29, np.nan, 32, 45],
    "Joining_Year": [2018, 2019, 2020, 2018, 2019, 2021, 2020, 2017]
}

df = pd.DataFrame(data)
df
# Out:
#       Name Department   Salary   Age  Joining_Year
# 0    Alice         HR  50000.0  25.0          2018
# 1      Bob         IT  60000.0  30.0          2019
# 2  Charlie         IT  75000.0  35.0          2020
# 3    David    Finance  80000.0  40.0          2018
# 4      Eva    Finance      NaN  29.0          2019
# 5    Frank         HR  55000.0   NaN          2021
# 6    Grace         IT  70000.0  32.0          2020
# 7    Helen    Finance  90000.0  45.0          2017

# %% [markdown]
# ## 🔹 2. Data Wrangling
# We will clean missing values and create a new feature (`Experience`).

# %%
# Fill missing values
df["Salary"].fillna(df["Salary"].mean(), inplace=True)
df["Age"].fillna(df["Age"].median(), inplace=True)

# Feature Engineering
df["Experience"] = 2025 - df["Joining_Year"]

df
# Out:
# /tmp/ipython-input-489367141.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Salary"].fillna(df["Salary"].mean(), inplace=True)
# /tmp/ipython-input-489367141.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ## 🔹 3. Data Exploration (EDA)
# Check summary statistics, data types, and correlations.

# %%
print("Summary Statistics:\n", df.describe())
print("\nData Types:\n", df.dtypes)
print("\nCorrelation:\n", df.corr(numeric_only=True))
# Out:
# Summary Statistics:
#               Salary        Age  Joining_Year  Experience
# count      8.000000   8.000000      8.000000    8.000000
# mean   68571.428571  33.500000   2019.000000    6.000000
# std    13286.482313   6.391959      1.309307    1.309307
# min    50000.000000  25.000000   2017.000000    4.000000
# 25%    58750.000000  29.750000   2018.000000    5.000000
# 50%    69285.714286  32.000000   2019.000000    6.000000
# 75%    76250.000000  36.250000   2020.000000    7.000000
# max    90000.000000  45.000000   2021.000000    8.000000
#
# Data Types:
#  Name             object
# Department       object
# Salary          float64
# Age             float64
# Joining_Year      int64
# Experience        int64
# dtype: object
#
# Correlation:
#                  Salary       Age  Joining_Year  Experience
# Salary        1.000000  0.902339     -0.451661    0.451661
# Age           0.902339  1.000000     -0.409673    0.409673
# ...

# %% [markdown]
# ## 🔹 4. Data Aggregation & Group Operations
# Compute **average salary by department**.

# %%
grouped = df.groupby("Department")["Salary"].mean()
grouped
# Out:
# Department
# Finance    79523.809524
# HR         52500.000000
# IT         68333.333333
# Name: Salary, dtype: float64

# %% [markdown]
# ## 🔹 5. Plotting & Visualization
# We will visualize the dataset using Matplotlib and Seaborn.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bar Plot - Average Salary by Department
plt.figure(figsize=(6,4))
sns.barplot(x=grouped.index, y=grouped.values, palette="viridis")
plt.title("Average Salary by Department")
plt.ylabel("Salary")
plt.xlabel("Department")
plt.show()
# Out:
# /tmp/ipython-input-2993248166.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=grouped.index, y=grouped.values, palette="viridis")

# %%
# Histogram - Age distribution
plt.figure(figsize=(6,4))
sns.histplot(df["Age"], bins=5, kde=True, color="blue")
plt.title("Age Distribution of Employees")
plt.show()

# %%
# Scatter Plot - Age vs Salary
plt.figure(figsize=(6,4))
sns.scatterplot(x="Age", y="Salary", data=df, hue="Department", style="Department", s=100)
plt.title("Age vs Salary by Department")
plt.show()

# %%
# Boxplot - Salary distribution by Department
plt.figure(figsize=(6,4))
sns.boxplot(x="Department", y="Salary", data=df, palette="Set2")
plt.title("Salary Distribution by Department")
plt.show()
# Out:
# /tmp/ipython-input-3803014878.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Department", y="Salary", data=df, palette="Set2")
